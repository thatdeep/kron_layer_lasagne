# %%
import time
import theano
import lasagne
import numpy as np

import theano.tensor as T

from utils import custom_sgd, iterate_minibatches
from kron_layer import KronLayer, SimpleKronLayer
from uv_kron_layer import UVKronLayer
from lowrank_layer import LowRankLayer, SimpleLowRankLayer


def build_custom_mlp(input_var=None, widths=None, drop_input=.2,
                     drop_hidden=.5, type="dense", rank=2):
    # By default, this creates the same network as `build_mlp`, but it can be
    # customized with respect to the number and size of hidden layers. This
    # mostly showcases how creating a network in Python code can be a lot more
    # flexible than a configuration file. Note that to make the code easier,
    # all the layers are just called `network` -- there is no need to give them
    # different names if all we return is the last one we created anyway; we
    # just used different names above for clarity.

    widths = widths if widths is not None else [100, 100]
    manifolds = {}

    # Input layer and dropout (with shortcut `dropout` for `DropoutLayer`):
    network = lasagne.layers.InputLayer(shape=(None, 1, 28, 28),
                                        input_var=input_var)
    if drop_input:
        network = lasagne.layers.dropout(network, p=drop_input)
    # Hidden layers and dropout:
    nonlin = lasagne.nonlinearities.rectify

    # Convolutional layer with 32 kernels of size 5x5. Strided and padded
    # convolutions are supported as well; see the docstring.
    network = lasagne.layers.Conv2DLayer(
            network, num_filters=32, filter_size=(5, 5),
            stride=1, pad=2,
            nonlinearity=lasagne.nonlinearities.rectify,
            W=lasagne.init.GlorotUniform())
    # Expert note: Lasagne provides alternative convolutional layers that
    # override Theano's choice of which implementation to use; for details
    # please see http://lasagne.readthedocs.org/en/latest/user/tutorial.html.
    network = lasagne.layers.MaxPool2DLayer(network, pool_size=(2, 2))

    # Another convolution with 32 5x5 kernels, and another 2x2 pooling:
    network = lasagne.layers.Conv2DLayer(
            network, num_filters=32, filter_size=(5, 5),
            stride=1, pad=2,
            nonlinearity=lasagne.nonlinearities.rectify)
    network = lasagne.layers.MaxPool2DLayer(network, pool_size=(2, 2))

    if type == "dense":
        network = lasagne.layers.DenseLayer(
            network, widths[0], nonlinearity=nonlin)
    else:
        if type == "lowrank":
            network = LowRankLayer(network,
                                   widths[0],
                                   rank=rank,
                                   name="rieman_low_rank_0")
            manifolds["rieman_low_rank_0"] = network.manifold
        elif type == "slowrank":
            network = LowRankLayer(network,
                                   widths[0],
                                   rank=rank,
                                   name="simple_low_rank_0")
        else:
            raise ValueError("type must be one of 2 variants: lowrank' or 'slowrank', but is '{}'".format(type))
    for width in widths[1:]:
        network = lasagne.layers.DenseLayer(
                network, width, nonlinearity=nonlin)
        if drop_hidden:
            network = lasagne.layers.dropout(network, p=drop_hidden)
    # Output layer:
    softmax = lasagne.nonlinearities.softmax
    network = lasagne.layers.DenseLayer(network, 10, nonlinearity=softmax)
    return network, manifolds


def generate_train_acc(input_X=None, target_y=None, widths=None, type="dense", lr=1e-2, rank=2):
    input_X = T.tensor4("X") if input_X is None else input_X
    target_y = T.vector("target Y integer", dtype='int32') if target_y is None else target_y
    widths = [100] if widths is None else widths
    dense_output, manifolds = build_custom_mlp(input_X, widths=widths, type=type, rank=rank)

    y_predicted = lasagne.layers.get_output(dense_output)


    all_weights = lasagne.layers.get_all_params(dense_output)


    loss = lasagne.objectives.categorical_crossentropy(y_predicted,target_y).mean()
    accuracy = lasagne.objectives.categorical_accuracy(y_predicted,target_y).mean()

    updates_sgd = custom_sgd(loss, all_weights, learning_rate=lr, manifolds=manifolds)


    train_fun = theano.function([input_X,target_y],[loss, accuracy],updates=updates_sgd)
    accuracy_fun = theano.function([input_X,target_y],accuracy)
    return train_fun, accuracy_fun


def comparison(X_train,y_train,X_val,y_val,X_test,y_test, kron_params=None):
    import pickle
    n_trials = 5
    kron_params = np.ones(n_trials, dtype=int) * 10 if kron_params is None else kron_params
    lr = 0.0316227766017
    num_epochs = 60

    batch_size = 100

    hidden_units = [256]

    trains, accs = generate_train_acc(widths=hidden_units, type="dense", lr=lr)
    trains, accs = list(zip(*([(trains, accs)]
                              + [generate_train_acc(widths=hidden_units, type="lowrank", lr=lr, rank=kron_param) for kron_param in kron_params]
                              + [generate_train_acc(widths=hidden_units, type="slowrank", lr=lr,rank=kron_param) for kron_param in kron_params])))

    names = ["dense"] + ["rieman_lowrank({})".format(i) for i in range(n_trials)]\
                      + ["simple_lowrank({})".format(i) for i in range(n_trials)]
    results = {}

    for train, acc, name in zip(trains, accs, names):
        res = {}
        res["train_fun"] = train
        res["accuracy_fun"] = acc
        res["train_err"] = []
        res["train_acc"] = []
        res["epoch_times"] = []
        res["val_acc"] = []
        results[name] = res

    for epoch in range(num_epochs):
        for (res_name, res) in results.items():
            train_err = 0
            train_acc = 0
            train_batches = 0
            start_time = time.time()
            for batch in iterate_minibatches(X_train, y_train,batch_size):
                inputs, targets = batch
                train_err_batch, train_acc_batch= res["train_fun"](inputs, targets)
                train_err += train_err_batch
                train_acc += train_acc_batch
                train_batches += 1

            # And a full pass over the validation data:
            val_acc = 0
            val_batches = 0
            for batch in iterate_minibatches(X_val, y_val, batch_size):
                inputs, targets = batch
                val_acc += res["accuracy_fun"](inputs, targets)
                val_batches += 1

            # Then we print the results for this epoch:
            print("for {}".format(res_name))
            print("Epoch {} of {} took {:.3f}s".format(
                epoch + 1, num_epochs, time.time() - start_time))

            print("  training loss (in-iteration):\t\t{:.6f}".format(train_err / train_batches))
            print("  train accuracy:\t\t{:.2f} %".format(
                train_acc / train_batches * 100))
            print("  validation accuracy:\t\t{:.2f} %".format(
                val_acc / val_batches * 100))
            res["train_err"].append(train_err / train_batches)
            res["train_acc"].append(train_acc / train_batches * 100)
            res["val_acc"].append(val_acc / val_batches * 100)
        temp = {key: [results[key]['train_fun'], results[key]['accuracy_fun']] for key in results}
        for res in results.values():
            res.pop('train_fun')
            res.pop('accuracy_fun')
        
        with open("compare_lowrank_10.dict", 'wb') as pickle_file:
            pickle.dump(results, pickle_file)
        for key in results:
            results[key]['train_fun'] = temp[key][0]
            results[key]['accuracy_fun'] = temp[key][1]

def determine(X_train,y_train,X_val,y_val,X_test,y_test, type="lowrank", lrates=None):
    lrates = np.logspace(-3, -1, 5) if lrates is None else lrates
    rank = 10
    import pickle
    num_epochs = 25

    batch_size = 100

    hidden_units = [256]

    trains, accs = list(zip(*([generate_train_acc(widths=hidden_units, type=type, rank=rank) for lr in lrates])))

    names = ["{}({})".format(type, lr) for lr in lrates]
    results = {}

    for train, acc, name in zip(trains, accs, names):
        res = {}
        res["train_fun"] = train
        res["accuracy_fun"] = acc
        res["train_err"] = []
        res["train_acc"] = []
        res["epoch_times"] = []
        res["val_acc"] = []
        results[name] = res

    for epoch in range(num_epochs):
        for (res_name, res) in results.items():
            train_err = 0
            train_acc = 0
            train_batches = 0
            start_time = time.time()
            for batch in iterate_minibatches(X_train, y_train,batch_size):
                inputs, targets = batch
                train_err_batch, train_acc_batch= res["train_fun"](inputs, targets)
                train_err += train_err_batch
                train_acc += train_acc_batch
                train_batches += 1

            # And a full pass over the validation data:
            val_acc = 0
            val_batches = 0
            for batch in iterate_minibatches(X_val, y_val, batch_size):
                inputs, targets = batch
                val_acc += res["accuracy_fun"](inputs, targets)
                val_batches += 1

            # Then we print the results for this epoch:
            print("for {}".format(res_name))
            print("Epoch {} of {} took {:.3f}s".format(
                epoch + 1, num_epochs, time.time() - start_time))

            print("  training loss (in-iteration):\t\t{:.6f}".format(train_err / train_batches))
            print("  train accuracy:\t\t{:.2f} %".format(
                train_acc / train_batches * 100))
            print("  validation accuracy:\t\t{:.2f} %".format(
                val_acc / val_batches * 100))
            res["train_err"].append(train_err / train_batches)
            res["train_acc"].append(train_acc / train_batches * 100)
            res["val_acc"].append(val_acc / val_batches * 100)
        temp = {key: [results[key]['train_fun'], results[key]['accuracy_fun']] for key in results}
        for res in results.values():
            res.pop('train_fun')
            res.pop('accuracy_fun')
        
        with open("determine_history_{}.dict".format(type), 'wb') as pickle_file:
            pickle.dump(results, pickle_file)
        for key in results:
            results[key]['train_fun'] = temp[key][0]
            results[key]['accuracy_fun'] = temp[key][1]

# %%
if __name__ == "__main__":
    from mnist import load_dataset
    X_train,y_train,X_val,y_val,X_test,y_test = load_dataset()
    print(X_train.shape,y_train.shape)

    determine(X_train,y_train,X_val,y_val,X_test,y_test, type="lowrank")
# Out:
# ((50000, 1, 28, 28), (50000,))
# for lowrank(0.1)
# Epoch 1 of 25 took 32.964s
#   training loss (in-iteration):		1.280312
#   train accuracy:		58.10 %
#   validation accuracy:		85.97 %
# for lowrank(0.001)
# Epoch 1 of 25 took 32.857s
#   training loss (in-iteration):		1.395296
#   train accuracy:		56.31 %
#   validation accuracy:		85.99 %
# for lowrank(0.0316227766017)
# Epoch 1 of 25 took 32.853s
#   training loss (in-iteration):		1.535191
#   train accuracy:		49.08 %
#   validation accuracy:		83.94 %
# for lowrank(0.01)
# Epoch 1 of 25 took 32.881s
#   training loss (in-iteration):		1.387994
#   train accuracy:		53.54 %
#   validation accuracy:		83.77 %
# for lowrank(0.00316227766017)
# Epoch 1 of 25 took 32.877s
#   training loss (in-iteration):		1.494428
#   train accuracy:		51.91 %
#   validation accuracy:		84.15 %
# for lowrank(0.1)
# Epoch 2 of 25 took 32.844s
#   training loss (in-iteration):		0.398253
#   train accuracy:		87.76 %
#   validation accuracy:		91.46 %
# for lowrank(0.001)
# Epoch 2 of 25 took 32.866s
#   training loss (in-iteration):		0.424116
#   train accuracy:		86.99 %
#   validation accuracy:		91.02 %
# for lowrank(0.0316227766017)
# Epoch 2 of 25 took 32.851s
#   training loss (in-iteration):		0.441045
#   train accuracy:		86.31 %
#   validation accuracy:		90.18 %
# for lowrank(0.01)
# Epoch 2 of 25 took 32.870s
#   training loss (in-iteration):		0.416424
#   train accuracy:		87.16 %
#   validation accuracy:		90.56 %
# for lowrank(0.00316227766017)
# Epoch 2 of 25 took 32.856s
#   training loss (in-iteration):		0.415972
#   train accuracy:		87.26 %
#   validation accuracy:		91.56 %
# for lowrank(0.1)
# Epoch 3 of 25 took 32.968s
#   training loss (in-iteration):		0.268790
#   train accuracy:		91.87 %
#   validation accuracy:		93.58 %
# for lowrank(0.001)
# Epoch 3 of 25 took 32.857s
#   training loss (in-iteration):		0.290364
#   train accuracy:		91.25 %
#   validation accuracy:		93.56 %
# for lowrank(0.0316227766017)
# Epoch 3 of 25 took 32.843s
#   training loss (in-iteration):		0.309400
#   train accuracy:		90.61 %
#   validation accuracy:		92.96 %
# for lowrank(0.01)
# Epoch 3 of 25 took 32.863s
#   training loss (in-iteration):		0.276498
#   train accuracy:		91.72 %
#   validation accuracy:		93.68 %
# for lowrank(0.00316227766017)
# Epoch 3 of 25 took 32.906s
#   training loss (in-iteration):		0.269896
#   train accuracy:		91.78 %
#   validation accuracy:		94.47 %
# for lowrank(0.1)
# Epoch 4 of 25 took 32.944s
#   training loss (in-iteration):		0.203810
#   train accuracy:		93.88 %
#   validation accuracy:		94.98 %
# for lowrank(0.001)
# Epoch 4 of 25 took 32.862s
#   training loss (in-iteration):		0.213356
#   train accuracy:		93.68 %
#   validation accuracy:		95.24 %
# for lowrank(0.0316227766017)
# Epoch 4 of 25 took 32.868s
#   training loss (in-iteration):		0.231138
#   train accuracy:		93.02 %
#   validation accuracy:		94.71 %
# for lowrank(0.01)
# Epoch 4 of 25 took 32.878s
#   training loss (in-iteration):		0.208014
#   train accuracy:		93.79 %
#   validation accuracy:		95.04 %
# for lowrank(0.00316227766017)
# Epoch 4 of 25 took 32.939s
#   training loss (in-iteration):		0.203436
#   train accuracy:		93.93 %
#   validation accuracy:		95.14 %
# for lowrank(0.1)
# Epoch 5 of 25 took 32.865s
#   training loss (in-iteration):		0.163648
#   train accuracy:		95.06 %
#   validation accuracy:		96.02 %
# for lowrank(0.001)
# Epoch 5 of 25 took 32.861s
#   training loss (in-iteration):		0.170638
#   train accuracy:		94.89 %
#   validation accuracy:		95.82 %
# for lowrank(0.0316227766017)
# Epoch 5 of 25 took 32.864s
#   training loss (in-iteration):		0.180598
#   train accuracy:		94.47 %
#   validation accuracy:		95.67 %
# for lowrank(0.01)
# Epoch 5 of 25 took 32.859s
#   training loss (in-iteration):		0.168653
#   train accuracy:		94.93 %
#   validation accuracy:		96.08 %
# for lowrank(0.00316227766017)
# Epoch 5 of 25 took 32.851s
#   training loss (in-iteration):		0.166583
#   train accuracy:		95.04 %
#   validation accuracy:		95.85 %
# for lowrank(0.1)
# Epoch 6 of 25 took 32.893s
#   training loss (in-iteration):		0.140197
#   train accuracy:		95.71 %
#   validation accuracy:		96.36 %
# for lowrank(0.001)
# Epoch 6 of 25 took 32.863s
#   training loss (in-iteration):		0.144091
#   train accuracy:		95.69 %
#   validation accuracy:		96.43 %
# for lowrank(0.0316227766017)
# Epoch 6 of 25 took 32.873s
#   training loss (in-iteration):		0.149817
#   train accuracy:		95.53 %
#   validation accuracy:		96.47 %
# for lowrank(0.01)
# Epoch 6 of 25 took 32.915s
#   training loss (in-iteration):		0.142750
#   train accuracy:		95.64 %
#   validation accuracy:		96.57 %
# for lowrank(0.00316227766017)
# Epoch 6 of 25 took 32.865s
#   training loss (in-iteration):		0.142584
#   train accuracy:		95.66 %
#   validation accuracy:		96.27 %
# for lowrank(0.1)
# Epoch 7 of 25 took 32.859s
#   training loss (in-iteration):		0.125335
#   train accuracy:		96.22 %
#   validation accuracy:		96.90 %
# for lowrank(0.001)
# Epoch 7 of 25 took 32.871s
#   training loss (in-iteration):		0.128477
#   train accuracy:		96.13 %
#   validation accuracy:		96.61 %
# for lowrank(0.0316227766017)
# Epoch 7 of 25 took 32.877s
#   training loss (in-iteration):		0.131059
#   train accuracy:		96.08 %
#   validation accuracy:		96.54 %
# for lowrank(0.01)
# Epoch 7 of 25 took 32.896s
#   training loss (in-iteration):		0.127278
#   train accuracy:		96.11 %
#   validation accuracy:		96.87 %
# for lowrank(0.00316227766017)
# Epoch 7 of 25 took 32.866s
#   training loss (in-iteration):		0.127826
#   train accuracy:		96.14 %
#   validation accuracy:		96.68 %
# for lowrank(0.1)
# Epoch 8 of 25 took 32.856s
#   training loss (in-iteration):		0.113357
#   train accuracy:		96.47 %
#   validation accuracy:		96.93 %
# for lowrank(0.001)
# Epoch 8 of 25 took 32.841s
#   training loss (in-iteration):		0.116756
#   train accuracy:		96.47 %
#   validation accuracy:		96.99 %
# for lowrank(0.0316227766017)
# Epoch 8 of 25 took 32.856s
#   training loss (in-iteration):		0.116395
#   train accuracy:		96.49 %
#   validation accuracy:		97.04 %
# for lowrank(0.01)
# Epoch 8 of 25 took 32.954s
#   training loss (in-iteration):		0.115005
#   train accuracy:		96.50 %
#   validation accuracy:		96.98 %
# for lowrank(0.00316227766017)
# Epoch 8 of 25 took 32.889s
#   training loss (in-iteration):		0.116232
#   train accuracy:		96.45 %
#   validation accuracy:		96.99 %
# for lowrank(0.1)
# Epoch 9 of 25 took 32.892s
#   training loss (in-iteration):		0.106025
#   train accuracy:		96.82 %
#   validation accuracy:		97.34 %
# for lowrank(0.001)
# Epoch 9 of 25 took 32.860s
#   training loss (in-iteration):		0.105937
#   train accuracy:		96.85 %
#   validation accuracy:		97.02 %
# for lowrank(0.0316227766017)
# Epoch 9 of 25 took 32.862s
#   training loss (in-iteration):		0.106356
#   train accuracy:		96.81 %
#   validation accuracy:		96.97 %
# for lowrank(0.01)
# Epoch 9 of 25 took 32.873s
#   training loss (in-iteration):		0.106862
#   train accuracy:		96.69 %
#   validation accuracy:		97.08 %
# for lowrank(0.00316227766017)
# Epoch 9 of 25 took 32.861s
#   training loss (in-iteration):		0.107132
#   train accuracy:		96.78 %
#   validation accuracy:		97.10 %
# for lowrank(0.1)
# Epoch 10 of 25 took 32.890s
#   training loss (in-iteration):		0.097540
#   train accuracy:		96.93 %
#   validation accuracy:		97.23 %
# for lowrank(0.001)
# Epoch 10 of 25 took 32.867s
#   training loss (in-iteration):		0.100363
#   train accuracy:		96.90 %
#   validation accuracy:		97.22 %
# for lowrank(0.0316227766017)
# Epoch 10 of 25 took 32.919s
#   training loss (in-iteration):		0.098972
#   train accuracy:		97.02 %
#   validation accuracy:		97.17 %
# for lowrank(0.01)
# Epoch 10 of 25 took 32.862s
#   training loss (in-iteration):		0.100772
#   train accuracy:		96.98 %
#   validation accuracy:		97.27 %
# for lowrank(0.00316227766017)
# Epoch 10 of 25 took 32.859s
#   training loss (in-iteration):		0.101167
#   train accuracy:		96.85 %
#   validation accuracy:		97.34 %
# for lowrank(0.1)
# Epoch 11 of 25 took 32.863s
#   training loss (in-iteration):		0.093087
#   train accuracy:		97.16 %
#   validation accuracy:		97.43 %
# for lowrank(0.001)
# Epoch 11 of 25 took 32.890s
#   training loss (in-iteration):		0.095186
#   train accuracy:		97.06 %
#   validation accuracy:		97.41 %
# for lowrank(0.0316227766017)
# Epoch 11 of 25 took 32.864s
#   training loss (in-iteration):		0.092959
#   train accuracy:		97.18 %
#   validation accuracy:		97.54 %
# for lowrank(0.01)
# Epoch 11 of 25 took 32.888s
#   training loss (in-iteration):		0.096393
#   train accuracy:		97.05 %
#   validation accuracy:		96.49 %
# for lowrank(0.00316227766017)
# Epoch 11 of 25 took 32.867s
#   training loss (in-iteration):		0.096059
#   train accuracy:		97.07 %
#   validation accuracy:		97.36 %
# for lowrank(0.1)
# Epoch 12 of 25 took 32.862s
#   training loss (in-iteration):		0.088390
#   train accuracy:		97.29 %
#   validation accuracy:		97.46 %
# for lowrank(0.001)
# Epoch 12 of 25 took 32.914s
#   training loss (in-iteration):		0.090510
#   train accuracy:		97.28 %
#   validation accuracy:		97.33 %
# for lowrank(0.0316227766017)
# Epoch 12 of 25 took 32.957s
#   training loss (in-iteration):		0.088290
#   train accuracy:		97.34 %
#   validation accuracy:		97.35 %
# for lowrank(0.01)
# Epoch 12 of 25 took 32.844s
#   training loss (in-iteration):		0.090962
#   train accuracy:		97.27 %
#   validation accuracy:		97.52 %
# for lowrank(0.00316227766017)
# Epoch 12 of 25 took 32.849s
#   training loss (in-iteration):		0.090277
#   train accuracy:		97.26 %
#   validation accuracy:		97.29 %
# for lowrank(0.1)
# Epoch 13 of 25 took 32.915s
#   training loss (in-iteration):		0.085247
#   train accuracy:		97.35 %
#   validation accuracy:		97.70 %
# for lowrank(0.001)
# Epoch 13 of 25 took 32.879s
#   training loss (in-iteration):		0.086215
#   train accuracy:		97.33 %
#   validation accuracy:		97.48 %
# for lowrank(0.0316227766017)
# Epoch 13 of 25 took 32.855s
#   training loss (in-iteration):		0.084929
#   train accuracy:		97.38 %
#   validation accuracy:		97.49 %
# for lowrank(0.01)
# Epoch 13 of 25 took 32.919s
#   training loss (in-iteration):		0.083798
#   train accuracy:		97.46 %
#   validation accuracy:		97.50 %
# for lowrank(0.00316227766017)
# Epoch 13 of 25 took 32.892s
#   training loss (in-iteration):		0.085337
#   train accuracy:		97.39 %
#   validation accuracy:		97.39 %
# for lowrank(0.1)
# Epoch 14 of 25 took 32.901s
#   training loss (in-iteration):		0.081981
#   train accuracy:		97.46 %
#   validation accuracy:		97.38 %
# for lowrank(0.001)
# Epoch 14 of 25 took 33.118s
#   training loss (in-iteration):		0.083140
#   train accuracy:		97.49 %
#   validation accuracy:		97.67 %
# for lowrank(0.0316227766017)
# Epoch 14 of 25 took 32.879s
#   training loss (in-iteration):		0.079991
#   train accuracy:		97.57 %
#   validation accuracy:		97.74 %
# for lowrank(0.01)
# Epoch 14 of 25 took 32.941s
#   training loss (in-iteration):		0.082547
#   train accuracy:		97.48 %
#   validation accuracy:		97.59 %
# for lowrank(0.00316227766017)
# Epoch 14 of 25 took 32.867s
#   training loss (in-iteration):		0.082473
#   train accuracy:		97.46 %
#   validation accuracy:		97.61 %
# for lowrank(0.1)
# Epoch 15 of 25 took 32.991s
#   training loss (in-iteration):		0.078507
#   train accuracy:		97.61 %
#   validation accuracy:		97.66 %
# for lowrank(0.001)
# Epoch 15 of 25 took 32.838s
#   training loss (in-iteration):		0.079079
#   train accuracy:		97.54 %
#   validation accuracy:		97.62 %
# for lowrank(0.0316227766017)
# Epoch 15 of 25 took 33.003s
#   training loss (in-iteration):		0.077312
#   train accuracy:		97.60 %
#   validation accuracy:		97.42 %
# for lowrank(0.01)
# Epoch 15 of 25 took 32.895s
#   training loss (in-iteration):		0.078527
#   train accuracy:		97.53 %
#   validation accuracy:		97.57 %
# for lowrank(0.00316227766017)
# Epoch 15 of 25 took 32.852s
#   training loss (in-iteration):		0.082134
#   train accuracy:		97.48 %
#   validation accuracy:		97.63 %
# for lowrank(0.1)
# Epoch 16 of 25 took 32.911s
#   training loss (in-iteration):		0.075979
#   train accuracy:		97.59 %
#   validation accuracy:		97.80 %
# for lowrank(0.001)
# Epoch 16 of 25 took 32.855s
#   training loss (in-iteration):		0.076066
#   train accuracy:		97.74 %
#   validation accuracy:		97.72 %
# for lowrank(0.0316227766017)
# Epoch 16 of 25 took 33.126s
#   training loss (in-iteration):		0.074229
#   train accuracy:		97.68 %
#   validation accuracy:		97.82 %
# for lowrank(0.01)
# Epoch 16 of 25 took 33.679s
#   training loss (in-iteration):		0.076628
#   train accuracy:		97.70 %
#   validation accuracy:		97.79 %
# for lowrank(0.00316227766017)
# Epoch 16 of 25 took 33.661s
#   training loss (in-iteration):		0.076912
#   train accuracy:		97.62 %
#   validation accuracy:		97.63 %
# for lowrank(0.1)
# Epoch 17 of 25 took 33.651s
#   training loss (in-iteration):		0.073158
#   train accuracy:		97.76 %
#   validation accuracy:		97.79 %
# for lowrank(0.001)
# Epoch 17 of 25 took 33.664s
#   training loss (in-iteration):		0.074781
#   train accuracy:		97.69 %
#   validation accuracy:		97.77 %
# for lowrank(0.0316227766017)
# Epoch 17 of 25 took 33.650s
#   training loss (in-iteration):		0.072272
#   train accuracy:		97.72 %
#   validation accuracy:		97.62 %
# for lowrank(0.01)
# Epoch 17 of 25 took 33.702s
#   training loss (in-iteration):		0.073744
#   train accuracy:		97.70 %
#   validation accuracy:		97.87 %
# for lowrank(0.00316227766017)
# Epoch 17 of 25 took 33.755s
#   training loss (in-iteration):		0.073635
#   train accuracy:		97.74 %
#   validation accuracy:		97.85 %
# for lowrank(0.1)
# Epoch 18 of 25 took 33.701s
#   training loss (in-iteration):		0.071072
#   train accuracy:		97.79 %
#   validation accuracy:		97.84 %
# for lowrank(0.001)
# Epoch 18 of 25 took 33.715s
#   training loss (in-iteration):		0.071710
#   train accuracy:		97.81 %
#   validation accuracy:		97.91 %
# for lowrank(0.0316227766017)
# Epoch 18 of 25 took 33.701s
#   training loss (in-iteration):		0.069470
#   train accuracy:		97.86 %
#   validation accuracy:		97.93 %
# for lowrank(0.01)
# Epoch 18 of 25 took 33.712s
#   training loss (in-iteration):		0.070879
#   train accuracy:		97.79 %
#   validation accuracy:		97.84 %
# for lowrank(0.00316227766017)
# Epoch 18 of 25 took 33.701s
#   training loss (in-iteration):		0.073181
#   train accuracy:		97.70 %
#   validation accuracy:		97.82 %
# for lowrank(0.1)
# Epoch 19 of 25 took 33.693s
#   training loss (in-iteration):		0.070249
#   train accuracy:		97.80 %
#   validation accuracy:		97.92 %
# for lowrank(0.001)
# Epoch 19 of 25 took 33.729s
#   training loss (in-iteration):		0.070191
#   train accuracy:		97.87 %
#   validation accuracy:		98.08 %
# for lowrank(0.0316227766017)
# Epoch 19 of 25 took 33.694s
#   training loss (in-iteration):		0.066780
#   train accuracy:		97.96 %
#   validation accuracy:		97.81 %
# for lowrank(0.01)
# Epoch 19 of 25 took 33.756s
#   training loss (in-iteration):		0.068674
#   train accuracy:		97.90 %
#   validation accuracy:		97.82 %
# for lowrank(0.00316227766017)
# Epoch 19 of 25 took 33.696s
#   training loss (in-iteration):		0.070040
#   train accuracy:		97.79 %
#   validation accuracy:		97.87 %
# for lowrank(0.1)
# Epoch 20 of 25 took 33.683s
#   training loss (in-iteration):		0.066865
#   train accuracy:		97.88 %
#   validation accuracy:		97.81 %
# for lowrank(0.001)
# Epoch 20 of 25 took 33.689s
#   training loss (in-iteration):		0.068008
#   train accuracy:		97.95 %
#   validation accuracy:		97.91 %
# for lowrank(0.0316227766017)
# Epoch 20 of 25 took 33.685s
#   training loss (in-iteration):		0.065144
#   train accuracy:		97.99 %
#   validation accuracy:		98.05 %
# for lowrank(0.01)
# Epoch 20 of 25 took 33.726s
#   training loss (in-iteration):		0.066848
#   train accuracy:		97.91 %
#   validation accuracy:		98.11 %
# for lowrank(0.00316227766017)
# Epoch 20 of 25 took 33.699s
#   training loss (in-iteration):		0.068430
#   train accuracy:		97.90 %
#   validation accuracy:		97.99 %
# for lowrank(0.1)
# Epoch 21 of 25 took 33.694s
#   training loss (in-iteration):		0.064647
#   train accuracy:		97.95 %
#   validation accuracy:		97.86 %
# for lowrank(0.001)
# Epoch 21 of 25 took 33.689s
#   training loss (in-iteration):		0.066633
#   train accuracy:		97.96 %
#   validation accuracy:		97.78 %
# for lowrank(0.0316227766017)
# Epoch 21 of 25 took 33.740s
#   training loss (in-iteration):		0.063845
#   train accuracy:		97.97 %
#   validation accuracy:		98.01 %
# for lowrank(0.01)
# Epoch 21 of 25 took 33.737s
#   training loss (in-iteration):		0.064332
#   train accuracy:		98.03 %
#   validation accuracy:		98.11 %
# for lowrank(0.00316227766017)
# Epoch 21 of 25 took 33.695s
#   training loss (in-iteration):		0.065341
#   train accuracy:		97.94 %
#   validation accuracy:		97.87 %
# for lowrank(0.1)
# Epoch 22 of 25 took 33.696s
#   training loss (in-iteration):		0.063669
#   train accuracy:		98.00 %
#   validation accuracy:		97.95 %
# for lowrank(0.001)
# Epoch 22 of 25 took 33.727s
#   training loss (in-iteration):		0.064589
#   train accuracy:		98.01 %
#   validation accuracy:		98.10 %
# for lowrank(0.0316227766017)
# Epoch 22 of 25 took 33.697s
#   training loss (in-iteration):		0.062556
#   train accuracy:		98.00 %
#   validation accuracy:		97.99 %
# for lowrank(0.01)
# Epoch 22 of 25 took 33.704s
#   training loss (in-iteration):		0.063737
#   train accuracy:		98.05 %
#   validation accuracy:		98.12 %
# for lowrank(0.00316227766017)
# Epoch 22 of 25 took 33.689s
#   training loss (in-iteration):		0.064602
#   train accuracy:		98.01 %
#   validation accuracy:		98.07 %
# for lowrank(0.1)
# Epoch 23 of 25 took 33.685s
#   training loss (in-iteration):		0.061121
#   train accuracy:		98.11 %
#   validation accuracy:		98.06 %
# for lowrank(0.001)
# Epoch 23 of 25 took 33.712s
#   training loss (in-iteration):		0.062669
#   train accuracy:		98.07 %
#   validation accuracy:		98.02 %
# for lowrank(0.0316227766017)
# Epoch 23 of 25 took 33.779s
#   training loss (in-iteration):		0.061408
#   train accuracy:		98.11 %
#   validation accuracy:		98.17 %
# for lowrank(0.01)
# Epoch 23 of 25 took 33.721s
#   training loss (in-iteration):		0.062772
#   train accuracy:		98.05 %
#   validation accuracy:		98.01 %
# for lowrank(0.00316227766017)
# Epoch 23 of 25 took 33.721s
#   training loss (in-iteration):		0.062616
#   train accuracy:		98.06 %
#   validation accuracy:		98.12 %
# for lowrank(0.1)
# Epoch 24 of 25 took 33.683s
#   training loss (in-iteration):		0.060185
#   train accuracy:		98.06 %
#   validation accuracy:		97.96 %
# for lowrank(0.001)
# Epoch 24 of 25 took 33.705s
#   training loss (in-iteration):		0.060909
#   train accuracy:		98.15 %
#   validation accuracy:		98.02 %
# for lowrank(0.0316227766017)
# Epoch 24 of 25 took 33.680s
#   training loss (in-iteration):		0.059314
#   train accuracy:		98.12 %
#   validation accuracy:		98.24 %
# for lowrank(0.01)
# Epoch 24 of 25 took 33.729s
#   training loss (in-iteration):		0.059492
#   train accuracy:		98.14 %
#   validation accuracy:		98.11 %
# for lowrank(0.00316227766017)
# Epoch 24 of 25 took 33.692s
#   training loss (in-iteration):		0.059639
#   train accuracy:		98.15 %
#   validation accuracy:		97.98 %
# for lowrank(0.1)
# Epoch 25 of 25 took 33.685s
#   training loss (in-iteration):		0.058734
#   train accuracy:		98.15 %
#   validation accuracy:		98.00 %
# for lowrank(0.001)
# Epoch 25 of 25 took 33.745s
#   training loss (in-iteration):		0.059913
#   train accuracy:		98.16 %
#   validation accuracy:		98.10 %
# for lowrank(0.0316227766017)
# Epoch 25 of 25 took 33.683s
#   training loss (in-iteration):		0.057811
#   train accuracy:		98.18 %
#   validation accuracy:		98.19 %
# for lowrank(0.01)
# Epoch 25 of 25 took 33.671s
#   training loss (in-iteration):		0.057936
#   train accuracy:		98.21 %
#   validation accuracy:		98.04 %
# for lowrank(0.00316227766017)
# Epoch 25 of 25 took 33.683s
#   training loss (in-iteration):		0.060401
#   train accuracy:		98.11 %
#   validation accuracy:		97.99 %
