# %%
import time
import theano
import lasagne
import numpy as np

import theano.tensor as T

from utils import custom_sgd, iterate_minibatches
from kron_layer import KronLayer
from lowrank_layer import LowRankLayer
from multi_kron_layer import MultiKronLayer
# Out:
# Using gpu device 0: GRID K520 (CNMeM is disabled)
# /home/ubuntu/anaconda2/lib/python2.7/site-packages/Theano-0.8.0.dev0-py2.7.egg/theano/tensor/signal/downsample.py:5: UserWarning: downsample module has been moved to the pool module.
#   warnings.warn("downsample module has been moved to the pool module.")
# Couldn't import dot_parser, loading of dot files will not be possible.

# %%
def build_custom_cnn(input_var=None, widths=None, drop_input=.2,
                     drop_hidden=.5, type="dense", params=None):
    # By default, this creates the same network as `build_mlp`, but it can be
    # customized with respect to the number and size of hidden layers. This
    # mostly showcases how creating a network in Python code can be a lot more
    # flexible than a configuration file. Note that to make the code easier,
    # all the layers are just called `network` -- there is no need to give them
    # different names if all we return is the last one we created anyway; we
    # just used different names above for clarity.

    params = params if params is not None else {}
    widths = widths if widths is not None else [100, 100]
    manifolds = {}

    # Input layer and dropout (with shortcut `dropout` for `DropoutLayer`):
    network = lasagne.layers.InputLayer(shape=(None, 1, 28, 28),
                                        input_var=input_var)
    if drop_input:
        network = lasagne.layers.dropout(network, p=drop_input)
    # Hidden layers and dropout:
    nonlin = lasagne.nonlinearities.rectify

    
    # Convolutional layer with 32 kernels of size 5x5. Strided and padded
    # convolutions are supported as well; see the docstring.
    network = lasagne.layers.Conv2DLayer(
            network, num_filters=32, filter_size=(5, 5),
            stride=1, pad=2,
            nonlinearity=lasagne.nonlinearities.rectify,
            W=lasagne.init.GlorotUniform())
    # Expert note: Lasagne provides alternative convolutional layers that
    # override Theano's choice of which implementation to use; for details
    # please see http://lasagne.readthedocs.org/en/latest/user/tutorial.html.
    network = lasagne.layers.MaxPool2DLayer(network, pool_size=(2, 2))

    # Another convolution with 32 5x5 kernels, and another 2x2 pooling:
    network = lasagne.layers.Conv2DLayer(
            network, num_filters=64, filter_size=(5, 5),
            stride=1, pad=2,
            nonlinearity=lasagne.nonlinearities.rectify)
    network = lasagne.layers.MaxPool2DLayer(network, pool_size=(2, 2))
    """
    network = lasagne.layers.Conv2DLayer(
            network, num_filters=32, filter_size=(5, 5),
            nonlinearity=lasagne.nonlinearities.rectify)
        
    network = lasagne.layers.Conv2DLayer(
            network, num_filters=32, filter_size=(5, 5),
            nonlinearity=lasagne.nonlinearities.rectify)
    
    # Max-pooling layer of factor 2 in both dimensions:
    network = lasagne.layers.MaxPool2DLayer(network, pool_size=(2, 2))
    network = lasagne.layers.MaxPool2DLayer(network, pool_size=(2, 2))
    """

    if drop_hidden:
        network = lasagne.layers.dropout(network, p=drop_hidden)
    if type == "dense":
        network = lasagne.layers.DenseLayer(
            network, widths[0], nonlinearity=nonlin)
    elif type == "lowrank":
        param_density = params.get('param_density', 1.0)
        network = LowRankLayer(network, widths[0], param_density=param_density, name="fixedrank0")
        manifolds["fixedrank0"] = network.manifold
    elif type == "kron":
        param_density = params.get('param_density', 1.0)
        #shape2 = params.get('shape2', (4, 4))
        #network = KronLayer(network, widths[0], shape2=shape2, param_density=param_density, name="kron_fixedrank0")
        mode = params.get('mode', 'fwh')
        network = MultiKronLayer(network, widths[0], mode=mode, param_density=param_density, name="kron_fixedrank0")
        manifolds.update(network.manifolds)
    else:
        raise ValueError("type must be one of 3 variants: 'dense', 'lowrank' or 'kron'")
    for width in widths[1:]:
        network = lasagne.layers.DenseLayer(
                network, width, nonlinearity=nonlin)
        if drop_hidden:
            network = lasagne.layers.dropout(network, p=drop_hidden)
    # Output layer:
    softmax = lasagne.nonlinearities.softmax
    network = lasagne.layers.DenseLayer(network, 10, nonlinearity=softmax)
    return network, manifolds

# %%
def generate_train_acc(input_X=None, target_y=None, widths=None, type="dense", learning_rate=0.01, params=None):
    input_X = T.tensor4("X") if input_X is None else input_X
    target_y = T.vector("target Y integer", dtype='int32') if target_y is None else target_y
    widths = [100] if widths is None else widths
    params = {'param_density': 0.5 } if params is None else params
    dense_output, manifolds = build_custom_cnn(input_X, widths=widths, type=type, params=params)
    #предсказание нейронки (theano-преобразование)
    y_predicted = lasagne.layers.get_output(dense_output)

    #все веса нейронки (shared-переменные)
    all_weights = lasagne.layers.get_all_params(dense_output)

    #функция ошибки - средняя кроссэнтропия
    loss = lasagne.objectives.categorical_crossentropy(y_predicted,target_y).mean()
    accuracy = lasagne.objectives.categorical_accuracy(y_predicted,target_y).mean()

    #сразу посчитать словарь обновлённых значений с шагом по градиенту, как раньше
    updates_sgd = custom_sgd(loss, all_weights, learning_rate=learning_rate, manifolds=manifolds)

    #функция, которая обучает сеть на 1 шаг и возвращащет значение функции потерь и точности
    train_fun = theano.function([input_X,target_y],[loss,accuracy],updates=updates_sgd)
    accuracy_fun = theano.function([input_X,target_y],accuracy)
    return train_fun, accuracy_fun

# %%
def comparison(X_train,y_train,X_val,y_val,X_test,y_test, kron_params=None):
    import pickle
    import sys
    #import cProfile
    kron_params = [{'param_density': p, 'mode': 'w'} for p in np.linspace(0.03, 0.0, 1, endpoint=False)] if kron_params is None else kron_params
    num_epochs = 401 #количество проходов по данным
    kron_params += [{'param_density': p, 'mode': 'fhw'} for p in np.linspace(0.03, 0.0, 1, endpoint=False)]

    batch_size = 200 #размер мини-батча

    hidden_units = [1024]

    
    names = ["dense"] + ["kron({})".format(p.values()) for p in kron_params]
    etas = [theano.shared(np.array(0.01, dtype=theano.config.floatX))] + \
    [theano.shared(np.array(0.01, dtype=theano.config.floatX)) for _ in kron_params]
    eta_decays = [np.array(0.9, dtype=theano.config.floatX) for _ in names]

    trains, accs = generate_train_acc(widths=hidden_units, type="dense", learning_rate=etas[0])
    trains, accs = list(zip(*([(trains, accs)] + [generate_train_acc(widths=hidden_units, type="kron", params=kron_param) 
                                                  for (kron_param, eta) in zip(kron_params, etas[1:])])))

    

    
    results = {}

    for train, acc, name, eta, eta_decay in zip(trains, accs, names, etas, eta_decays):
        res = {}
        res["train_fun"] = train
        res["accuracy_fun"] = acc
        res["train_err"] = []
        res["train_acc"] = []
        res["epoch_times"] = []
        res["val_acc"] = []
        res["eta"] = eta
        res["eta_decay"] = eta_decay
        results[name] = res

    #pr = cProfile.Profile()
    #pr.enable()
    for epoch in range(num_epochs):
        for (res_name, res) in results.items():
            train_err = 0
            train_acc = 0
            train_batches = 0
            start_time = time.time()
            for batch in iterate_minibatches(X_train, y_train,batch_size):
                inputs, targets = batch
                train_err_batch, train_acc_batch= res["train_fun"](inputs, targets)
                train_err += train_err_batch
                train_acc += train_acc_batch
                train_batches += 1

            # And a full pass over the validation data:
            val_acc = 0
            val_batches = 0
            for batch in iterate_minibatches(X_val, y_val, batch_size):
                inputs, targets = batch
                val_acc += res["accuracy_fun"](inputs, targets)
                val_batches += 1

            # Then we print the results for this epoch:
            if epoch % 10 == 0:
                print("for {}".format(res_name))
                print("Epoch {} of {} took {:.3f}s".format(
                    epoch + 1, num_epochs, time.time() - start_time))
                res["eta"].set_value(res["eta"].get_value() * res["eta_decay"])
                print("  training loss (in-iteration):\t\t{:.6f}".format(train_err / train_batches))
                print("  train accuracy:\t\t{:.2f} %".format(
                    train_acc / train_batches * 100))
                print("  validation accuracy:\t\t{:.2f} %".format(
                    val_acc / val_batches * 100))
                sys.stdout.flush()
            res["train_err"].append(train_err / train_batches)
            res["train_acc"].append(train_acc / train_batches * 100)
            res["val_acc"].append(val_acc / val_batches * 100)
        cargo = {}
        for name, res in results.items():
            cargo[name] = {}
            cargo[name]['train_fun'] = res['train_fun']
            cargo[name]['accuracy_fun'] = res['accuracy_fun']
            cargo[name]['eta'] = res['eta']
            cargo[name]['eta_decay'] = res['eta_decay']
            res.pop('train_fun')
            res.pop('accuracy_fun')
            res.pop('eta')
            res.pop('eta_decay')
        with open("results/401_history.dict", 'wb') as pickle_file:
            pickle.dump(results, pickle_file)
        for name, res in results.items():
            res.update(cargo[name])
    for res in results.values():
        res.pop('train_fun')
        res.pop('accuracy_fun')
        res.pop('eta')
        res.pop('eta_decay')
    with open("401_history.dict", 'wb') as pickle_file:
        pickle.dump(results, pickle_file)
    #pr.disable()
    #pr.print_stats(sort='cumtime')

# %%
from mnist.mnist import load_dataset
X_train,y_train,X_val,y_val,X_test,y_test = load_dataset()
print(X_train.shape,y_train.shape)

comparison(X_train,y_train,X_val,y_val,X_test,y_test)
# Out:
# ((50000, 1, 28, 28), (50000,))
# dense parameters: 3211264
# input shape: (None, 64, 7, 7)
# number_of_params for kron_fixedrank0kron_w: 87396
# {'kron_fixedrank0kron_w': <manifolds.fixed_rank_embeeded.FixedRankEmbeeded object at 0x7f8033ae5910>}
# dense parameters: 3211264
# input shape: (None, 64, 7, 7)
# number_of_params for kron_fixedrank0kron_h: 29124
# number_of_params for kron_fixedrank0kron_f: 54465
# number_of_params for kron_fixedrank0kron_w: 29124
# {'kron_fixedrank0kron_w': <manifolds.fixed_rank_embeeded.FixedRankEmbeeded object at 0x7f8028d6b8d0>, 'kron_fixedrank0kron_f': <manifolds.fixed_rank_embeeded.FixedRankEmbeeded object at 0x7f8028d96750>, 'kron_fixedrank0kron_h': <manifolds.fixed_rank_embeeded.FixedRankEmbeeded object at 0x7f8028d9cc10>}
# for kron(['fhw', 0.029999999999999999])
# Epoch 1 of 401 took 100.834s
#   training loss (in-iteration):		2.299873
#   train accuracy:		15.74 %
#   validation accuracy:		20.02 %
# for kron(['w', 0.029999999999999999])
# Epoch 1 of 401 took 78.459s
#   training loss (in-iteration):		2.293346
#   train accuracy:		17.56 %
#   validation accuracy:		13.67 %
# for dense
# Epoch 1 of 401 took 10.932s
#   training loss (in-iteration):		1.797871
#   train accuracy:		43.99 %
#   validation accuracy:		74.89 %
# for kron(['fhw', 0.029999999999999999])
# Epoch 11 of 401 took 99.465s
#   training loss (in-iteration):		0.398914
#   train accuracy:		87.98 %
#   validation accuracy:		89.79 %
# for kron(['w', 0.029999999999999999])
# Epoch 11 of 401 took 80.854s
#   training loss (in-iteration):		0.280114
#   train accuracy:		91.63 %
#   validation accuracy:		92.87 %
# for dense
# Epoch 11 of 401 took 11.104s
#   training loss (in-iteration):		0.169420
#   train accuracy:		94.83 %
#   validation accuracy:		95.36 %
# for kron(['fhw', 0.029999999999999999])
# Epoch 21 of 401 took 97.646s
#   training loss (in-iteration):		0.211778
#   train accuracy:		93.62 %
#   validation accuracy:		94.37 %
# for kron(['w', 0.029999999999999999])
# Epoch 21 of 401 took 77.544s
#   training loss (in-iteration):		0.176411
#   train accuracy:		94.67 %
#   validation accuracy:		95.30 %
# for dense
# Epoch 21 of 401 took 10.925s
#   training loss (in-iteration):		0.122097
#   train accuracy:		96.28 %
#   validation accuracy:		96.61 %
# for kron(['fhw', 0.029999999999999999])
# Epoch 31 of 401 took 97.180s
#   training loss (in-iteration):		0.156275
#   train accuracy:		95.29 %
#   validation accuracy:		95.73 %
# for kron(['w', 0.029999999999999999])
# Epoch 31 of 401 took 77.397s
#   training loss (in-iteration):		0.138803
#   train accuracy:		95.77 %
#   validation accuracy:		96.36 %
# for dense
# Epoch 31 of 401 took 10.917s
#   training loss (in-iteration):		0.101578
#   train accuracy:		96.81 %
#   validation accuracy:		97.17 %
# for kron(['fhw', 0.029999999999999999])
# Epoch 41 of 401 took 103.048s
#   training loss (in-iteration):		0.131392
#   train accuracy:		95.93 %
#   validation accuracy:		96.36 %
# for kron(['w', 0.029999999999999999])
# Epoch 41 of 401 took 86.332s
#   training loss (in-iteration):		0.116518
#   train accuracy:		96.49 %
#   validation accuracy:		96.66 %
# for dense
# Epoch 41 of 401 took 11.131s
#   training loss (in-iteration):		0.086484
#   train accuracy:		97.32 %
#   validation accuracy:		97.48 %
# for kron(['fhw', 0.029999999999999999])
# Epoch 51 of 401 took 149.295s
#   training loss (in-iteration):		0.119490
#   train accuracy:		96.29 %
#   validation accuracy:		96.66 %
# for kron(['w', 0.029999999999999999])
# Epoch 51 of 401 took 111.461s
#   training loss (in-iteration):		0.106034
#   train accuracy:		96.68 %
#   validation accuracy:		97.04 %
# for dense
# Epoch 51 of 401 took 20.670s
#   training loss (in-iteration):		0.081499
#   train accuracy:		97.40 %
#   validation accuracy:		97.64 %
# for kron(['fhw', 0.029999999999999999])
# Epoch 61 of 401 took 109.702s
#   training loss (in-iteration):		0.108818
#   train accuracy:		96.58 %
#   validation accuracy:		96.93 %
# for kron(['w', 0.029999999999999999])
# Epoch 61 of 401 took 79.431s
#   training loss (in-iteration):		0.092895
#   train accuracy:		97.19 %
#   validation accuracy:		97.18 %
# for dense
# Epoch 61 of 401 took 10.924s
#   training loss (in-iteration):		0.074920
#   train accuracy:		97.60 %
#   validation accuracy:		97.54 %
# for kron(['fhw', 0.029999999999999999])
# Epoch 71 of 401 took 148.338s
#   training loss (in-iteration):		0.099733
#   train accuracy:		96.89 %
#   validation accuracy:		97.25 %
# for kron(['w', 0.029999999999999999])
# Epoch 71 of 401 took 109.427s
#   training loss (in-iteration):		0.088607
#   train accuracy:		97.26 %
#   validation accuracy:		97.40 %
# for dense
# Epoch 71 of 401 took 20.577s
#   training loss (in-iteration):		0.070722
#   train accuracy:		97.77 %
#   validation accuracy:		97.58 %
# for kron(['fhw', 0.029999999999999999])
# Epoch 81 of 401 took 152.171s
#   training loss (in-iteration):		0.092761
#   train accuracy:		97.13 %
#   validation accuracy:		97.33 %
# for kron(['w', 0.029999999999999999])
# Epoch 81 of 401 took 111.651s
#   training loss (in-iteration):		0.080420
#   train accuracy:		97.50 %
#   validation accuracy:		97.58 %
# for dense
# Epoch 81 of 401 took 20.806s
#   training loss (in-iteration):		0.067659
#   train accuracy:		97.89 %
#   validation accuracy:		97.70 %
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-e2df3bbbaae8> in <module>()
#       3 print(X_train.shape,y_train.shape)
#       4
# ----> 5 comparison(X_train,y_train,X_val,y_val,X_test,y_test)
#
# <ipython-input-4-5b4ce43c6584> in comparison(X_train, y_train, X_val, y_val, X_test, y_test, kron_params)
#      47             for batch in iterate_minibatches(X_train, y_train,batch_size):
#      48                 inputs, targets = batch
# ---> 49                 train_err_batch, train_acc_batch= res["train_fun"](inputs, targets)
#      50                 train_err += train_err_batch
#      51                 train_acc += train_acc_batch
#
# /home/ubuntu/anaconda2/lib/python2.7/site-packages/Theano-0.8.0.dev0-py2.7.egg/theano/compile/function_module.pyc in __call__(self, *args, **kwargs)
#     857         t0_fn = time.time()
#     858         try:
# --> 859             outputs = self.fn()
#     860         except Exception:
#     861             if hasattr(self.fn, 'position_of_error'):
#
# /home/ubuntu/anaconda2/lib/python2.7/site-packages/Theano-0.8.0.dev0-py2.7.egg/theano/gof/op.pyc in rval(p, i, o, n)
#     905         if params is graph.NoParams:
#     906             # default arguments are stored in the closure of `rval`
# --> 907             def rval(p=p, i=node_input_storage, o=node_output_storage, n=node):
#     908                 r = p(n, [x[0] for x in i], o)
#     909                 for o in node.outputs:
#
# KeyboardInterrupt:
